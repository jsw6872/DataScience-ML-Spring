# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/ralbu85/Lecture_DeepLearning_2022/main/simple.csv')
df
# Out:
#             X          y
# 0    0.542312   4.216289
# 1    0.541676   2.874347
# 2   -2.344561  11.687971
# 3    1.220562   0.512072
# 4    2.011580  -3.117803
# ..        ...        ...
# 995 -1.378233  10.731244
# 996 -0.154483   4.602639
# 997 -0.097741   3.282276
# 998 -1.309402   9.394069
# 999 -0.225035   3.260692
#
# [1000 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['X'], df['y'])

# %% [markdown]
# ## 딥러닝 모형 만들기

# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers

print(tf.__version__)
# Out:
# 2.10.0

# %%
model=keras.Sequential([
    layers.Dense(1, input_shape=[1]) # y 출력값이 1개, x도 1개라서 1, [1]
])

# %% [markdown]
# ### 학습 알고리즘 사용

# %%
optimizer = keras.optimizers.Adam(learning_rate = 0.01)

# %% [markdown]
# ## 모델과 옵티마이저 연결

# %%
model.compile(optimizer = optimizer, loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_2 (Dense)             (None, 1)                 2
#
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 모델의 학습

# %%
X = np.array(df['X'])
y = np.array(df['y'])

# %%
first_model = model.fit(X, y, epochs=50)
# Out:
# Epoch 1/50
# 26/32 [=======================>......] - ETA: 0s - loss: 22.2193
# 2022-10-13 13:23:01.856589: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 32/32 [==============================] - 0s 5ms/step - loss: 21.8032
# Epoch 2/50
# 32/32 [==============================] - 0s 4ms/step - loss: 18.2573
# Epoch 3/50
# 32/32 [==============================] - 0s 4ms/step - loss: 15.1834
# Epoch 4/50
# 32/32 [==============================] - 0s 4ms/step - loss: 12.5805
# Epoch 5/50
# 32/32 [==============================] - 0s 4ms/step - loss: 10.3876
# Epoch 6/50
# 32/32 [==============================] - 0s 4ms/step - loss: 8.5595
# Epoch 7/50
# 32/32 [==============================] - 0s 3ms/step - loss: 7.0558
# Epoch 8/50
# 32/32 [==============================] - 0s 4ms/step - loss: 5.8223
# Epoch 9/50
# 32/32 [==============================] - 0s 4ms/step - loss: 4.8175
# Epoch 10/50
# ...

# %% [markdown]
# ## 학습 기록 보기

# %%
first_model.history
# Out:
# {'loss': [0.922487199306488,
#   0.921555757522583,
#   0.9211046099662781,
#   0.9218170642852783,
#   0.921390950679779,
#   0.9218757748603821,
#   0.9222098588943481,
#   0.9224815964698792,
#   0.9195114374160767,
#   0.9214034080505371,
#   0.9217903017997742,
#   0.9218344688415527,
#   0.9213757514953613,
#   0.9216669201850891,
#   0.9217442870140076,
#   0.9211754202842712,
#   0.9213828444480896,
#   0.9214362502098083,
#   0.9202263951301575,
#   0.9216336607933044,
#   0.9225545525550842,
#   0.9217817783355713,
#   0.9215978384017944,
#   0.9215691685676575,
#   0.9215298295021057,
#   0.9219400882720947,
#   0.9216007590293884,
#   0.9207955002784729,
#   0.9215994477272034,
#   0.9204530715942383,
#   0.9214059710502625,
#   0.9214699268341064,
#   0.9212063550949097,
#   0.9218639731407166,
#   0.9211012721061707,
#   0.9227657914161682,
#   0.9220516681671143,
#   0.9212456345558167,
#   0.921491265296936,
#   0.9213284254074097,
#   0.9218707084655762,
# ...

# %%
plt.plot(first_model.history['loss'])

# %% [markdown]
# ## 모델의 예측

# %%
y_pred = model.predict(X)
y_pred
# Out:
# 32/32 [==============================] - 0s 2ms/step
# 2022-10-13 13:23:50.649331: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# array([[ 2.3432579e+00],
#        [ 2.3454325e+00],
#        [ 1.2207827e+01],
#        [ 2.5647163e-02],
#        [-2.6772943e+00],
#        [-3.8113952e+00],
#        [ 1.9412410e+00],
#        [ 1.5307667e+00],
#        [ 3.1787748e+00],
#        [ 4.9598317e+00],
#        [ 8.0442286e+00],
#        [ 9.8426476e+00],
#        [ 9.4596281e+00],
#        [ 7.7945318e+00],
#        [ 9.1336403e+00],
#        [ 3.6721368e+00],
#        [-2.0442162e+00],
#        [-4.1617579e+00],
#        [ 2.1410017e+00],
#        [ 7.5408554e-01],
#        [-2.7080755e+00],
#        [ 3.1718059e+00],
#        [ 3.3039927e+00],
#        [-1.1220560e+00],
#        [ 3.9227259e+00],
#        [ 7.6531544e+00],
#        [ 1.9222937e+00],
#        [ 6.3997936e+00],
#        [ 8.2764816e+00],
# ...

# %%
plt.scatter(X,y, color = 'blue')
plt.scatter(X, y_pred, color = 'green')

# %%
model.get_weights()
# Out:
# [array([[-3.417043]], dtype=float32), array([4.196361], dtype=float32)]
