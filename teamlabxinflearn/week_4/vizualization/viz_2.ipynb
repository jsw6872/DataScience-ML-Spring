# %% [markdown]
# # Maplotlib basic

# %% [markdown]
# ### Scatter

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data_1 = np.random.rand(512, 2)
data_2 = np.random.rand(512, 2)

# %%
plt.scatter(data_1[:,0], data_1[:,1], c="y")
plt.scatter(data_2[:,0], data_2[:,1], c="r", marker="v")

plt.show()

# %% [markdown]
# ### phone data

# %%
df = pd.read_csv("../data/phone_data.csv")
df.head()
# Out:
#    index            date  duration  item    month   network network_type
# 0      0  15/10/14 06:58    34.429  data  2014-11      data         data
# 1      1  15/10/14 06:58    13.000  call  2014-11  Vodafone       mobile
# 2      2  15/10/14 14:46    23.000  call  2014-11    Meteor       mobile
# 3      3  15/10/14 14:48     4.000  call  2014-11     Tesco       mobile
# 4      4  15/10/14 17:27     4.000  call  2014-11     Tesco       mobile

# %%
def parsedate(date_info):
    # import datetime
    return date_info[:9]

# %%
df["day"] = df["date"].map(parsedate)
df.head()
# Out:
#    index            date  duration  item    month   network network_type  \
# 0      0  15/10/14 06:58    34.429  data  2014-11      data         data
# 1      1  15/10/14 06:58    13.000  call  2014-11  Vodafone       mobile
# 2      2  15/10/14 14:46    23.000  call  2014-11    Meteor       mobile
# 3      3  15/10/14 14:48     4.000  call  2014-11     Tesco       mobile
# 4      4  15/10/14 17:27     4.000  call  2014-11     Tesco       mobile
#
#          day
# 0  15/10/14
# 1  15/10/14
# 2  15/10/14
# 3  15/10/14
# 4  15/10/14

# %%
result = df.groupby(["network","day"])["duration"].sum().reset_index()
networks = result["network"].unique().tolist()
colors = ["b","g","r","c","m","y","k"]

# figure 반환
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

for network_name, color in zip(networks, colors):
    if network_name == "data":
        continue
    
    # X : day / Y : duration
    X_1 = result[result["network"] == network_name]["day"]
    Y_1 = result[result["network"] == network_name]["duration"]

    # 데이터를 쌓음
    ax.scatter(X_1, Y_1, c = color, label = network_name)
    ax.get_xaxis().set_visible(False)

ax.set_xlabel("day")
ax.set_ylabel("duration")

plt.legend(shadow = True, fancybox = True, loc="upper right")

# %%
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N))**2

# %%
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# ### Bar chart

# %%
data = [[5., 25., 50., 20.],
        [4., 23., 51., 17],
        [6., 22., 52., 19]]

X = np.arange(0,8,2)

# %%
plt.bar(X + 0.00, data[0], color = 'b', width = 0.30)
plt.bar(X + 0.5, data[1], color = 'g', width = 0.30)
plt.bar(X + 1.0, data[2], color = 'r', width = 0.30)
plt.xticks(X+0.50, ("A","B","C", "D"))
plt.show()

# %%
data = np.array([[5., 25., 50., 20.],
        [4., 23., 51., 17],
        [6., 22., 52., 19]])

color_list = ['b', 'g', 'r']
data_label = ["A","B","C"]
X = np.arange(data.shape[1])
X
# Out:
# array([0, 1, 2, 3])

# %%
data = np.array([[5., 5., 5., 5.],
        [4., 23., 51., 17],
        [6., 22., 52., 19]])

for i in range(3):
    plt.bar(X, data[i], bottom = np.sum(data[:i], axis=0), 
            color = color_list[i], label=data_label[i])
plt.legend()
plt.show()

# %%
A = [5., 30., 45., 22.]
B = [5, 25, 50, 20]

X = range(4)

plt.bar(X, A, color = 'b')
plt.bar(X, B, color = 'r', bottom = 60)

# yticks를 통해 
plt.yticks([0, 60], ["","TT"])
plt.show()

# %%
women_pop = np.array([5, 30, 45, 22])
men_pop = np.array([5, 25, 50, 20])
X = np.arange(4)
# horizontal
plt.barh(X, women_pop, color = 'r')
plt.barh(X, -men_pop, color = 'b')
plt.show()

# %% [markdown]
# ## histogram

# %%
X = np.random.randn(1000000)
plt.hist(X,bins=10000)
plt.show()

# %% [markdown]
# ## boxplot

# %%
data = np.random.randn(100,5)
# plt.boxplot(data)

# plt.boxplot(data, notch=True)
plt.boxplot(data, vert=True, whis=0.9)

plt.show()
